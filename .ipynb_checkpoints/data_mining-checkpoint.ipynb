# %%
import pandas as pd;
import matplotlib.pyplot as plt;
import numpy as np;

# %%
playstore = pd.read_csv('data/google_playstore/googleplaystore.csv')
user_rate = pd.read_csv('data/google_playstore/googleplaystore_user_reviews.csv')

# %%
playstore.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
user_rate.head(3)
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN

# %%
playstore.shape, user_rate.shape
# Out:
# ((10841, 13), (64295, 5))

# %%
playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
user_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
combined_data = pd.merge(playstore, user_rate, on='App', how='inner')

# %%
combined_data.head(5)
# Out:
#                    App        Category  Rating Reviews Size  Installs  Type  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 1  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 2  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 3  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 4  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
#
#   Price Content Rating                     Genres      Last Updated  \
# 0     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 1     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 3     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 4     0       Everyone  Art & Design;Pretend Play  January 15, 2018
#
#   Current Ver   Android Ver  \
# 0       2.0.0  4.0.3 and up
# 1       2.0.0  4.0.3 and up
# 2       2.0.0  4.0.3 and up
# 3       2.0.0  4.0.3 and up
# 4       2.0.0  4.0.3 and up
#
#                                    Translated_Review Sentiment  \
# 0  A kid's excessive ads. The types ads allowed a...  Negative
# 1                                         It bad >:(  Negative
# 2                                               like   Neutral
# 3                                                NaN       NaN
# 4                           I love colors inspyering  Positive
#
#    Sentiment_Polarity  Sentiment_Subjectivity
# 0              -0.250                1.000000
# 1              -0.725                0.833333
# 2               0.000                0.000000
# 3                 NaN                     NaN
# 4               0.500                0.600000

# %%
combined_data.shape
# Out:
# (122662, 17)

# %%
combined_data = combined_data.drop_duplicates()

# %%
combined_data.shape
# Out:
# (41661, 17)

# %%
combined_data.isnull().sum()
# Out:
# App                          0
# Category                     0
# Rating                      39
# Reviews                      0
# Size                         0
# Installs                     0
# Type                         0
# Price                        0
# Content Rating               0
# Genres                       0
# Last Updated                 0
# Current Ver                  0
# Android Ver                  0
# Translated_Review         1247
# Sentiment                 1239
# Sentiment_Polarity        1239
# Sentiment_Subjectivity    1239
# dtype: int64

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41661 entries, 0 to 122622
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     41661 non-null  object
#  1   Category                41661 non-null  object
#  2   Rating                  41622 non-null  float64
#  3   Reviews                 41661 non-null  object
#  4   Size                    41661 non-null  object
#  5   Installs                41661 non-null  object
#  6   Type                    41661 non-null  object
#  7   Price                   41661 non-null  object
#  8   Content Rating          41661 non-null  object
#  9   Genres                  41661 non-null  object
#  10  Last Updated            41661 non-null  object
#  11  Current Ver             41661 non-null  object
#  12  Android Ver             41661 non-null  object
#  13  Translated_Review       40414 non-null  object
#  14  Sentiment               40422 non-null  object
#  15  Sentiment_Polarity      40422 non-null  float64
#  16  Sentiment_Subjectivity  40422 non-null  float64
# dtypes: float64(3), object(14)
# memory usage: 5.7+ MB

# %%
combined_data['Rating'] = combined_data.groupby('Category')['Rating'].transform(
    lambda x: x.fillna(x.mean())
)

# %%
combined_data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
an_features = combined_data[['App', 'Category', 'Rating', 'Reviews', 'Installs','Sentiment', 'Sentiment_Polarity',
       'Sentiment_Subjectivity']]

# %%
an_features['Installs'].unique()
# Out:
# array(['500,000+', '1,000,000+', '100,000+', '5,000,000+', '10,000+',
#        '10,000,000+', '100,000,000+', '1,000,000,000+', '50,000,000+',
#        '500,000,000+', '1,000+', '50,000+', '5,000+'], dtype=object)

# %%
 an_features['Reviews']=an_features['Reviews'].astype(int)
an_features['Installs'] = an_features['Installs'].replace({',': '', '\\+': ''}, regex=True).astype(int)
# Out:
# /var/folders/_n/mh77c04n67s44f90qd0gnw5h0000gn/T/ipykernel_1937/2367688812.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   an_features['Reviews']=an_features['Reviews'].astype(int)
# /var/folders/_n/mh77c04n67s44f90qd0gnw5h0000gn/T/ipykernel_1937/2367688812.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   an_features['Installs'] = an_features['Installs'].replace({',': '', '\\+': ''}, regex=True).astype(int)

# %%
an_features['Sentiment'].unique()
# Out:
# array(['Negative', 'Neutral', nan, 'Positive'], dtype=object)

# %%
an_features['Sentiment_Polarity'] = an_features['Sentiment_Polarity'].fillna(0)
an_features['Sentiment'] = an_features['Sentiment'].fillna('Neutral')
# Out:
# /var/folders/_n/mh77c04n67s44f90qd0gnw5h0000gn/T/ipykernel_1937/2980459954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   an_features['Sentiment_Polarity'] = an_features['Sentiment_Polarity'].fillna(0)
# /var/folders/_n/mh77c04n67s44f90qd0gnw5h0000gn/T/ipykernel_1937/2980459954.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   an_features['Sentiment'] = an_features['Sentiment'].fillna('Neutral')

# %%
an_features.isnull().sum()
# Out:
# App                          0
# Category                     0
# Rating                       0
# Reviews                      0
# Installs                     0
# Sentiment                    0
# Sentiment_Polarity           0
# Sentiment_Subjectivity    1239
# dtype: int64

# %%
an_features.shape
# Out:
# (41661, 8)

# %%
an_features
# Out:
#                                        App        Category  Rating  Reviews  \
# 0                      Coloring book moana  ART_AND_DESIGN     3.9      967
# 1                      Coloring book moana  ART_AND_DESIGN     3.9      967
# 2                      Coloring book moana  ART_AND_DESIGN     3.9      967
# 3                      Coloring book moana  ART_AND_DESIGN     3.9      967
# 4                      Coloring book moana  ART_AND_DESIGN     3.9      967
# ...                                    ...             ...     ...      ...
# 122580  Firefox Focus: The privacy browser   COMMUNICATION     4.4    36981
# 122581  Firefox Focus: The privacy browser   COMMUNICATION     4.4    36981
# 122589  Firefox Focus: The privacy browser   COMMUNICATION     4.4    36981
# 122617  Firefox Focus: The privacy browser   COMMUNICATION     4.4    36981
# 122622                         FP Notebook         MEDICAL     4.5      410
#
#         Installs Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0         500000  Negative           -0.250000                1.000000
# 1         500000  Negative           -0.725000                0.833333
# 2         500000   Neutral            0.000000                0.000000
# 3         500000   Neutral            0.000000                     NaN
# 4         500000  Positive            0.500000                0.600000
# ...          ...       ...                 ...                     ...
# 122580   1000000   Neutral            0.000000                0.000000
# 122581   1000000  Positive            0.493750                0.700000
# 122589   1000000  Positive            0.535119                0.714286
# 122617   1000000  Positive            0.225000                0.426786
# 122622     50000   Neutral            0.000000                     NaN
#
# [41661 rows x 8 columns]

# %%
avg_sentiment_category = an_features.groupby('Category')['Sentiment_Polarity'].mean()
avg_sentiment_category.plot(kind='bar', figsize=(12, 6), title='Average Sentiment Polarity by Category')
# Out:
# <Axes: title={'center': 'Average Sentiment Polarity by Category'}, xlabel='Category'>

# %%
an_features.groupby(['App','Category'])[['Rating','Reviews','Installs']].mean()
# Out:
#                                                                      Rating  \
# App                                              Category
# 10 Best Foods for You                            HEALTH_AND_FITNESS     4.0
# 11st                                             SHOPPING               3.8
# 1800 Contacts - Lens Store                       MEDICAL                4.7
# 1LINE – One Line with One Touch                  GAME                   4.6
# 2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif PERSONALIZATION        4.2
# ...                                                                     ...
# Hotspot Shield Free VPN Proxy & Wi-Fi Security   TOOLS                  4.2
# Hotstar                                          ENTERTAINMENT          4.3
# Hotwire Hotel & Car Rental App                   TRAVEL_AND_LOCAL       4.3
# Housing-Real Estate & Property                   LIFESTYLE              4.1
# Houzz Interior Design Ideas                      HOUSE_AND_HOME         4.6
#
#                                                                        Reviews  \
# App                                              Category
# 10 Best Foods for You                            HEALTH_AND_FITNESS     2490.0
# 11st                                             SHOPPING              48732.0
# 1800 Contacts - Lens Store                       MEDICAL               23160.0
# 1LINE – One Line with One Touch                  GAME                 214878.0
# 2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif PERSONALIZATION      115773.0
# ...                                                                        ...
# Hotspot Shield Free VPN Proxy & Wi-Fi Security   TOOLS               1116393.0
# Hotstar                                          ENTERTAINMENT       4885646.0
# Hotwire Hotel & Car Rental App                   TRAVEL_AND_LOCAL      10323.0
# Housing-Real Estate & Property                   LIFESTYLE             28301.0
# Houzz Interior Design Ideas                      HOUSE_AND_HOME       353804.0
#
#                                                                         Installs
# App                                              Category
# 10 Best Foods for You                            HEALTH_AND_FITNESS     500000.0
# 11st                                             SHOPPING             10000000.0
# 1800 Contacts - Lens Store                       MEDICAL               1000000.0
# 1LINE – One Line with One Touch                  GAME                 10000000.0
# 2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif PERSONALIZATION      10000000.0
# ...                                                                          ...
# Hotspot Shield Free VPN Proxy & Wi-Fi Security   TOOLS                50000000.0
# Hotstar                                          ENTERTAINMENT       100000000.0
# Hotwire Hotel & Car Rental App                   TRAVEL_AND_LOCAL      1000000.0
# Housing-Real Estate & Property                   LIFESTYLE             1000000.0
# Houzz Interior Design Ideas                      HOUSE_AND_HOME       10000000.0
#
# [1063 rows x 3 columns]

# %%
av_features= an_features.groupby(['App','Category'])[['Rating','Reviews','Installs']].mean()

# %%
features = ['Rating', 'Reviews','Installs']
av_features[features].hist(bins=20, figsize=(10, 8), color='brown', edgecolor='gray')
plt.suptitle('Distribution of Features', fontsize=16)
plt.show()

# %%
av_features['Log_Reviews'] = np.log1p(av_features['Reviews'])
av_features['Log_Rating'] = np.log1p(av_features['Rating'])
av_features['Log_Installs'] = np.log1p(av_features['Installs'])

# %%
features = ['Log_Reviews', 'Log_Rating','Log_Installs']
av_features[features].hist(bins=20, figsize=(10, 8), color='brown', edgecolor='gray')
plt.suptitle('Distribution of Features (normalized)', fontsize=16)
plt.show()

# %%
av_features = av_features.reset_index()

# %%
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy

# Prepare the data for the surprise library
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(av_features[['App', 'Log_Reviews', 'Log_Rating']], reader)

# %%
# Split the data into training and test sets
trainset, testset = train_test_split(data, test_size=0.25)

# %%
# Use the SVD algorithm for recommendations
algo = SVD()
algo.fit(trainset)

# %%
# Make predictions
predictions = algo.test(testset)
accuracy.rmse(predictions)
# Out:
# RMSE: 0.0638
# 0.06383501072950971

# %%
# convert categorical data to numeric
av_features_catbrk = pd.get_dummies(av_features, columns=['Category'], drop_first=False)

# %%
av_features_catbrk.head(3)
# Out:
#                           App  Rating  Reviews    Installs  Log_Reviews  \
# 0       10 Best Foods for You     4.0   2490.0    500000.0     7.820440
# 1                        11st     3.8  48732.0  10000000.0    10.794112
# 2  1800 Contacts - Lens Store     4.7  23160.0   1000000.0    10.050225
#
#    Log_Rating  Log_Installs  Category_ART_AND_DESIGN  \
# 0    1.609438     13.122365                    False
# 1    1.568616     16.118096                    False
# 2    1.740466     13.815512                    False
#
#    Category_AUTO_AND_VEHICLES  Category_BEAUTY  ...  Category_PERSONALIZATION  \
# 0                       False            False  ...                     False
# 1                       False            False  ...                     False
# 2                       False            False  ...                     False
#
#    Category_PHOTOGRAPHY  Category_PRODUCTIVITY  Category_SHOPPING  \
# 0                 False                  False              False
# 1                 False                  False               True
# 2                 False                  False              False
#
#    Category_SOCIAL  Category_SPORTS  Category_TOOLS  \
# 0            False            False           False
# 1            False            False           False
# 2            False            False           False
#
#    Category_TRAVEL_AND_LOCAL  Category_VIDEO_PLAYERS  Category_WEATHER
# 0                      False                   False             False
# 1                      False                   False             False
# 2                      False                   False             False
#
# [3 rows x 40 columns]

# %%
# lets start our mode with content-based filtering
from sklearn.metrics.pairwise import cosine_similarity

features = ['Log_Rating', 'Log_Reviews','Log_Installs'] + list(av_features_catbrk.columns[av_features_catbrk.columns.str.contains('Category_')])
similarity_matrix = cosine_similarity(av_features_catbrk[features])

# %%
def recommend_apps(app, similarity_matrix, playstore, num_recoms=10):
    app_index = av_features_catbrk[av_features_catbrk['App'] == app].index[0]
    similar_indices = similarity_matrix[app_index].argsort()[::-1][1:num_recoms+1]
    #return av_features_catbrk.iloc[similar_indices][['App','Rating','Reviews']]
    return av_features_catbrk.sort_values(by='Rating', ascending=False).head(num_recoms)

# %%
recomms = recommend_apps("Coloring book moana", similarity_matrix, av_features_catbrk, num_recoms=10)[['App','Rating','Reviews']]

# %%
recomms
# Out:
#                                                     App  Rating    Reviews
# 693                                      FREE LIVE TALK     4.9      776.0
# 582                       Down Dog: Great Yoga Anywhere     4.9    28945.0
# 314                      CDL Practice Test 2018 Edition     4.9     7774.0
# 524               DMV Permit Practice Test 2018 Edition     4.9     6090.0
# 912                      GoodRx Drug Prices and Coupons     4.8    59158.0
# 529   DU Recorder – Screen Recorder, Video Editor, Live     4.8  2588730.0
# 667          Even - organize your money, get paid early     4.8    12304.0
# 751                        Find a Way: Addictive Puzzle     4.8    39480.0
# 1038                        Home Workout - No Equipment     4.8   430158.0
# 1039                Home Workout for Men - Bodybuilding     4.8    12705.0

# %%
recomms.merge(av_features[['App', 'Category']], on='App', how='left')
# Out:
#                                                  App  Rating    Reviews  \
# 0                                     FREE LIVE TALK     4.9      776.0
# 1                      Down Dog: Great Yoga Anywhere     4.9    28945.0
# 2                     CDL Practice Test 2018 Edition     4.9     7774.0
# 3              DMV Permit Practice Test 2018 Edition     4.9     6090.0
# 4                     GoodRx Drug Prices and Coupons     4.8    59158.0
# 5  DU Recorder – Screen Recorder, Video Editor, Live     4.8  2588730.0
# 6         Even - organize your money, get paid early     4.8    12304.0
# 7                       Find a Way: Addictive Puzzle     4.8    39480.0
# 8                        Home Workout - No Equipment     4.8   430158.0
# 9                Home Workout for Men - Bodybuilding     4.8    12705.0
#
#              Category
# 0              DATING
# 1  HEALTH_AND_FITNESS
# 2   AUTO_AND_VEHICLES
# 3   AUTO_AND_VEHICLES
# 4             MEDICAL
# 5       VIDEO_PLAYERS
# 6             FINANCE
# 7              FAMILY
# 8  HEALTH_AND_FITNESS
# 9  HEALTH_AND_FITNESS

# %% [markdown]
# ### Lets Explore clustering models

# %%
similarity_matrix.shape
# Out:
# (1063, 1063)

# %%
for_clustering = av_features

# %%
for_clustering
# Out:
#                                                    App            Category  \
# 0                                10 Best Foods for You  HEALTH_AND_FITNESS
# 1                                                 11st            SHOPPING
# 2                           1800 Contacts - Lens Store             MEDICAL
# 3                      1LINE – One Line with One Touch                GAME
# 4     2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif     PERSONALIZATION
# ...                                                ...                 ...
# 1058    Hotspot Shield Free VPN Proxy & Wi-Fi Security               TOOLS
# 1059                                           Hotstar       ENTERTAINMENT
# 1060                    Hotwire Hotel & Car Rental App    TRAVEL_AND_LOCAL
# 1061                    Housing-Real Estate & Property           LIFESTYLE
# 1062                       Houzz Interior Design Ideas      HOUSE_AND_HOME
#
#       Rating    Reviews     Installs  Log_Reviews  Log_Rating  Log_Installs
# 0        4.0     2490.0     500000.0     7.820440    1.609438     13.122365
# 1        3.8    48732.0   10000000.0    10.794112    1.568616     16.118096
# 2        4.7    23160.0    1000000.0    10.050225    1.740466     13.815512
# 3        4.6   214878.0   10000000.0    12.277830    1.722767     16.118096
# 4        4.2   115773.0   10000000.0    11.659395    1.648659     16.118096
# ...      ...        ...          ...          ...         ...           ...
# 1058     4.2  1116393.0   50000000.0    13.925614    1.648659     17.727534
# 1059     4.3  4885646.0  100000000.0    15.401812    1.667707     18.420681
# 1060     4.3    10323.0    1000000.0     9.242227    1.667707     13.815512
# 1061     4.1    28301.0    1000000.0    10.250688    1.629241     13.815512
# 1062     4.6   353804.0   10000000.0    12.776501    1.722767     16.118096
#
# [1063 rows x 8 columns]

# %%
from sklearn.cluster import KMeans

# Fit a K-Means model on the normalized data
kmeans = KMeans(n_clusters=5, random_state=42)
for_clustering['Cluster'] = kmeans.fit_predict(for_clustering[['Log_Reviews', 'Log_Rating', 'Log_Installs']])

# %%
for_clustering.head(10)
# Out:
#                                                 App            Category  \
# 0                             10 Best Foods for You  HEALTH_AND_FITNESS
# 1                                              11st            SHOPPING
# 2                        1800 Contacts - Lens Store             MEDICAL
# 3                   1LINE – One Line with One Touch                GAME
# 4  2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif     PERSONALIZATION
# 5                      21-Day Meditation Experience  HEALTH_AND_FITNESS
# 6               2Date Dating App, Love and matching              DATING
# 7                       2GIS: directory & navigator    TRAVEL_AND_LOCAL
# 8                                         2RedBeans              DATING
# 9                     2ndLine - Second Phone Number       COMMUNICATION
#
#    Rating   Reviews    Installs  Log_Reviews  Log_Rating  Log_Installs  \
# 0     4.0    2490.0    500000.0     7.820440    1.609438     13.122365
# 1     3.8   48732.0  10000000.0    10.794112    1.568616     16.118096
# 2     4.7   23160.0   1000000.0    10.050225    1.740466     13.815512
# 3     4.6  214878.0  10000000.0    12.277830    1.722767     16.118096
# 4     4.2  115773.0  10000000.0    11.659395    1.648659     16.118096
# 5     4.4   11506.0    100000.0     9.350711    1.686399     11.512935
# 6     4.4   41605.0    500000.0    10.636000    1.686399     13.122365
# 7     4.5  768833.0  50000000.0    13.552630    1.704748     17.727534
# 8     4.0     337.0     10000.0     5.823046    1.609438      9.210440
# 9     4.2   15880.0   1000000.0     9.672879    1.648659     13.815512
#
#    Cluster
# 0        4
# 1        2
# 2        0
# 3        2
# 4        2
# 5        4
# 6        0
# 7        1
# 8        3
# 9        0

# %%
# Recommend apps within the same cluster
def recommend_from_cluster(app_name, data, top_n=5):
    app_cluster = data[data['App'] == app_name]['Cluster'].values[0]
    cluster_apps = data[data['Cluster'] == app_cluster]
    return cluster_apps.head(top_n)

recommendations = recommend_from_cluster("21-Day Meditation Experience", for_clustering)
print(recommendations)
# Out:
#                                        App            Category  Rating  \
# 0                    10 Best Foods for You  HEALTH_AND_FITNESS     4.0
# 5             21-Day Meditation Experience  HEALTH_AND_FITNESS     4.4
# 15                              4 in a Row                GAME     3.8
# 16  4K Wallpapers and Ultra HD Backgrounds     PERSONALIZATION     4.6
# 17           7 Cups: Anxiety & Stress Chat  HEALTH_AND_FITNESS     4.2
#
#     Reviews  Installs  Log_Reviews  Log_Rating  Log_Installs  Cluster
# 0    2490.0  500000.0     7.820440    1.609438     13.122365        4
# 5   11506.0  100000.0     9.350711    1.686399     11.512935        4
# 15   4257.0  500000.0     8.356555    1.568616     13.122365        4
# 16   7583.0  500000.0     8.933796    1.722767     13.122365        4
# 17  13799.0  500000.0     9.532424    1.648659     13.122365        4

# %%
for_clustering[for_clustering['App'] == app_name]['Cluster'].values[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 for_clustering[for_clustering['App'] == app_name]['Cluster'].values[0]
#
# NameError: name 'app_name' is not defined

# %%
import matplotlib.pyplot as plt

plt.scatter(for_clustering['Log_Installs'], for_clustering['Log_Reviews'], c=for_clustering['Cluster'], cmap='viridis')
plt.xlabel("Installs")
plt.ylabel("Review")
plt.title("K-Means Clustering")
plt.colorbar(label='Cluster')
plt.show()

# %%
from sklearn.metrics import silhouette_score

# Compute the silhouette score
sil_score = silhouette_score(for_clustering[['Log_Reviews', 'Log_Rating', 'Log_Installs']], for_clustering['Cluster'])
print(f"Silhouette Score: {sil_score}")
# Out:
# Silhouette Score: 0.45032891928814206

# %%
for_clustering2 = av_features

# %%
# Fit a K-Means model on the normalized data
kmeans = KMeans(n_clusters=10, random_state=42)
for_clustering2['Cluster'] = kmeans.fit_predict(for_clustering2[['Log_Reviews', 'Log_Rating', 'Log_Installs']])

# %%
for_clustering2.head(10)
# Out:
#                                                 App            Category  \
# 0                             10 Best Foods for You  HEALTH_AND_FITNESS
# 1                                              11st            SHOPPING
# 2                        1800 Contacts - Lens Store             MEDICAL
# 3                   1LINE – One Line with One Touch                GAME
# 4  2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif     PERSONALIZATION
# 5                      21-Day Meditation Experience  HEALTH_AND_FITNESS
# 6               2Date Dating App, Love and matching              DATING
# 7                       2GIS: directory & navigator    TRAVEL_AND_LOCAL
# 8                                         2RedBeans              DATING
# 9                     2ndLine - Second Phone Number       COMMUNICATION
#
#    Rating   Reviews    Installs  Log_Reviews  Log_Rating  Log_Installs  \
# 0     4.0    2490.0    500000.0     7.820440    1.609438     13.122365
# 1     3.8   48732.0  10000000.0    10.794112    1.568616     16.118096
# 2     4.7   23160.0   1000000.0    10.050225    1.740466     13.815512
# 3     4.6  214878.0  10000000.0    12.277830    1.722767     16.118096
# 4     4.2  115773.0  10000000.0    11.659395    1.648659     16.118096
# 5     4.4   11506.0    100000.0     9.350711    1.686399     11.512935
# 6     4.4   41605.0    500000.0    10.636000    1.686399     13.122365
# 7     4.5  768833.0  50000000.0    13.552630    1.704748     17.727534
# 8     4.0     337.0     10000.0     5.823046    1.609438      9.210440
# 9     4.2   15880.0   1000000.0     9.672879    1.648659     13.815512
#
#    Cluster
# 0        5
# 1        4
# 2        7
# 3        3
# 4        3
# 5        5
# 6        0
# 7        1
# 8        6
# 9        7

# %% [markdown]
# #### clustering did not do well on recommecdation, lets try encrease number of clustering

# %%
def recommend_from_cluster2(app_name, data, top_n=12):
    app_cluster = data[data['App'] == app_name]['Cluster'].values[0]
    cluster_apps = data[data['Cluster'] == app_cluster]
    return cluster_apps.head(top_n)

recommendations2 = recommend_from_cluster2("21-Day Meditation Experience", for_clustering2)
print(recommendations2)
# Out:
#                                        App             Category  Rating  \
# 0                    10 Best Foods for You   HEALTH_AND_FITNESS     4.0
# 5             21-Day Meditation Experience   HEALTH_AND_FITNESS     4.4
# 15                              4 in a Row                 GAME     3.8
# 16  4K Wallpapers and Ultra HD Backgrounds      PERSONALIZATION     4.6
# 20          7 Weeks - Habit & Goal Tracker         PRODUCTIVITY     4.4
# 25         95Live -SG#1 Live Streaming App               DATING     4.1
# 26                A Call From Santa Claus!               FAMILY     3.9
# 28                            A Word A Day               FAMILY     3.7
# 47                                ARY NEWS   NEWS_AND_MAGAZINES     4.4
# 48                           ARY NEWS URDU   NEWS_AND_MAGAZINES     4.4
# 72              Adult Dating - AdultFinder               DATING     3.3
# 94                      All Maths Formulas  BOOKS_AND_REFERENCE     4.4
#
#     Reviews   Installs  Log_Reviews  Log_Rating  Log_Installs  Cluster
# 0    2490.0   500000.0     7.820440    1.609438     13.122365        5
# 5   11506.0   100000.0     9.350711    1.686399     11.512935        5
# 15   4257.0   500000.0     8.356555    1.568616     13.122365        5
# 16   7583.0   500000.0     8.933796    1.722767     13.122365        5
# 20   6011.0   500000.0     8.701513    1.686399     13.122365        5
# 25   4953.5  1000000.0     8.508052    1.629241     13.815512        5
# 26   3720.0  1000000.0     8.221748    1.589235     13.815512        5
# 28   2398.0   500000.0     7.782807    1.547563     13.122365        5
# 47   2959.0  1000000.0     7.992945    1.686399     13.815512        5
# 48   1071.0   500000.0     6.977281    1.686399     13.122365        5
# 72   1601.0   500000.0     7.379008    1.458615     13.122365        5
# 94   2709.0  1000000.0     7.904704    1.686399     13.815512        5

# %% [markdown]
# #### Still increasing nnumber of clsutering did not work fine, now lets try to compasate "Category" during clustering

# %%
cat_cluster = av_features

# %%
# lets Perform one-hot encoding on 'Category'
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
cat_cluster['Category_Encoded'] = label_encoder.fit_transform(cat_cluster['Category'])

# %%
cat_cluster.head(5)
# Out:
#                                                 App            Category  \
# 0                             10 Best Foods for You  HEALTH_AND_FITNESS
# 1                                              11st            SHOPPING
# 2                        1800 Contacts - Lens Store             MEDICAL
# 3                   1LINE – One Line with One Touch                GAME
# 4  2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif     PERSONALIZATION
#
#    Rating   Reviews    Installs  Log_Reviews  Log_Rating  Log_Installs  \
# 0     4.0    2490.0    500000.0     7.820440    1.609438     13.122365
# 1     3.8   48732.0  10000000.0    10.794112    1.568616     16.118096
# 2     4.7   23160.0   1000000.0    10.050225    1.740466     13.815512
# 3     4.6  214878.0  10000000.0    12.277830    1.722767     16.118096
# 4     4.2  115773.0  10000000.0    11.659395    1.648659     16.118096
#
#    Cluster  Category_Encoded
# 0        5                15
# 1        4                26
# 2        7                20
# 3        3                14
# 4        3                23

# %%
cat_cluster = cat_cluster.drop(['Log_Reviews','Log_Rating','Log_Installs'],axis=1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(cat_cluster[['Rating', 'Reviews', 'Installs']])

# Combine scaled numerical features with encoded categories
if 'Category_Encoded' in cat_cluster:
    cluster_data = pd.concat([pd.DataFrame(scaled_features, columns=['Rating', 'Reviews', 'Installs']),
                              cat_cluster['Category_Encoded']], axis=1)
else:
    cluster_data = pd.concat([pd.DataFrame(scaled_features, columns=['Rating', 'Reviews', 'Installs']),
                              category_encoded], axis=1)

# %%
cat_cluster
# Out:
#                                                    App            Category  \
# 0                                10 Best Foods for You  HEALTH_AND_FITNESS
# 1                                                 11st            SHOPPING
# 2                           1800 Contacts - Lens Store             MEDICAL
# 3                      1LINE – One Line with One Touch                GAME
# 4     2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif     PERSONALIZATION
# ...                                                ...                 ...
# 1058    Hotspot Shield Free VPN Proxy & Wi-Fi Security               TOOLS
# 1059                                           Hotstar       ENTERTAINMENT
# 1060                    Hotwire Hotel & Car Rental App    TRAVEL_AND_LOCAL
# 1061                    Housing-Real Estate & Property           LIFESTYLE
# 1062                       Houzz Interior Design Ideas      HOUSE_AND_HOME
#
#       Rating    Reviews     Installs  Cluster  Category_Encoded
# 0        4.0     2490.0     500000.0        5                15
# 1        3.8    48732.0   10000000.0        4                26
# 2        4.7    23160.0    1000000.0        7                20
# 3        4.6   214878.0   10000000.0        3                14
# 4        4.2   115773.0   10000000.0        3                23
# ...      ...        ...          ...      ...               ...
# 1058     4.2  1116393.0   50000000.0        1                29
# 1059     4.3  4885646.0  100000000.0        8                 9
# 1060     4.3    10323.0    1000000.0        7                30
# 1061     4.1    28301.0    1000000.0        0                18
# 1062     4.6   353804.0   10000000.0        3                16
#
# [1063 rows x 7 columns]

# %%
# Fit K-Means with the updated features
kmeans = KMeans(n_clusters=5, random_state=42)
cat_cluster['Cluster'] = kmeans.fit_predict(cluster_data)

# %%
# Check category distribution within each cluster
for cluster in cat_cluster['Cluster'].unique():
    cluster_apps = cat_cluster[cat_cluster['Cluster'] == cluster]
    top_categories = cluster_apps['Category'].value_counts().head(3)
    print(f"Cluster {cluster} - Top Categories:\n{top_categories}\n")
# Out:
# Cluster 0 - Top Categories:
# Category
# GAME                  105
# HEALTH_AND_FITNESS     47
# FOOD_AND_DRINK         20
# Name: count, dtype: int64
#
# Cluster 1 - Top Categories:
# Category
# TOOLS               54
# TRAVEL_AND_LOCAL    46
# PRODUCTIVITY        46
# Name: count, dtype: int64
#
# Cluster 3 - Top Categories:
# Category
# MEDICAL            47
# PERSONALIZATION    44
# PHOTOGRAPHY        43
# Name: count, dtype: int64
#
# Cluster 2 - Top Categories:
# Category
# DATING           48
# COMMUNICATION    42
# EDUCATION        31
# Name: count, dtype: int64
#
# Cluster 4 - Top Categories:
# Category
# FAMILY           112
# FINANCE           46
# ENTERTAINMENT     33
# Name: count, dtype: int64

# %%
# lets improve our recommendation funnction 
def recommend_from_cluster(app_name, data, top_n=10):
    app_cluster = data[data['App'] == app_name]['Cluster'].values[0]
    app_category = data[data['App'] == app_name]['Category'].values[0]
    
    # Filter by cluster and category
    cluster_apps = data[(data['Cluster'] == app_cluster) & (data['Category'] == app_category)]
    return cluster_apps.sort_values(by='Rating', ascending=False).head(top_n)

# %%
recommendations = recommend_from_cluster("Coloring book moana", cat_cluster)
print(recommendations[['App', 'Category', 'Rating', 'Cluster']])
# Out:
#                                                    App        Category  \
# 376  Canva: Poster, banner, card maker & graphic de...  ART_AND_DESIGN
# 458                      Colorfit - Drawing & Coloring  ART_AND_DESIGN
# 128                          Anime Manga Coloring Book  ART_AND_DESIGN
# 13     3D Color Pixel by Number - Sandbox Art Coloring  ART_AND_DESIGN
# 869                               Garden Coloring Book  ART_AND_DESIGN
# 768                      FlipaClip - Cartoon animation  ART_AND_DESIGN
# 593                      Drawing Clothes Fashion Ideas  ART_AND_DESIGN
# 625                                 Easy Origami Ideas  ART_AND_DESIGN
# 126                              Animated Photo Editor  ART_AND_DESIGN
# 277          Boys Photo Editor - Six Pack & Men's Suit  ART_AND_DESIGN
#
#      Rating  Cluster
# 376     4.7        2
# 458     4.7        2
# 128     4.5        2
# 13      4.4        2
# 869     4.4        2
# 768     4.3        2
# 593     4.2        2
# 625     4.2        2
# 126     4.1        2
# 277     4.1        2

# %%
## scaaled feature dataset
scaled_ft= pd.DataFrame(scaled_features, columns=['Rating', 'Reviews', 'Installs'])

# %%
scaled_ft
# Out:
#         Rating   Reviews  Installs
# 0     0.625000  0.000031  0.000499
# 1     0.541667  0.000623  0.009999
# 2     0.916667  0.000296  0.000999
# 3     0.875000  0.002749  0.009999
# 4     0.708333  0.001481  0.009999
# ...        ...       ...       ...
# 1058  0.708333  0.014286  0.049999
# 1059  0.750000  0.062521  0.099999
# 1060  0.750000  0.000131  0.000999
# 1061  0.666667  0.000361  0.000999
# 1062  0.875000  0.004527  0.009999
#
# [1063 rows x 3 columns]

# %%
scaled_domain = pd.concat([pd.DataFrame(scaled_features, columns=['Rating', 'Reviews', 'Installs']),
                              cat_cluster['Cluster']], axis=1)

# %%
scaled_domain.head(3)
# Out:
#      Rating   Reviews  Installs  Cluster
# 0  0.625000  0.000031  0.000499        0
# 1  0.541667  0.000623  0.009999        1
# 2  0.916667  0.000296  0.000999        3

# %%
# Calculate silhouette score
score = silhouette_score(cluster_data, cat_cluster['Cluster'])
print(f"Silhouette Score: {score:.2f}")
# Out:
# Silhouette Score: 0.58

# %%
#### Letst explore recommendation with TrancatedSVD with cosign similaarities
trnc_svd = av_features.drop(['Log_Reviews','Log_Rating','Log_Installs','Cluster','Category_Encoded'],axis=1)

# %%
trnc_svd
# Out:
#                                                    App            Category  \
# 0                                10 Best Foods for You  HEALTH_AND_FITNESS
# 1                                                 11st            SHOPPING
# 2                           1800 Contacts - Lens Store             MEDICAL
# 3                      1LINE – One Line with One Touch                GAME
# 4     2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif     PERSONALIZATION
# ...                                                ...                 ...
# 1058    Hotspot Shield Free VPN Proxy & Wi-Fi Security               TOOLS
# 1059                                           Hotstar       ENTERTAINMENT
# 1060                    Hotwire Hotel & Car Rental App    TRAVEL_AND_LOCAL
# 1061                    Housing-Real Estate & Property           LIFESTYLE
# 1062                       Houzz Interior Design Ideas      HOUSE_AND_HOME
#
#       Rating    Reviews     Installs
# 0        4.0     2490.0     500000.0
# 1        3.8    48732.0   10000000.0
# 2        4.7    23160.0    1000000.0
# 3        4.6   214878.0   10000000.0
# 4        4.2   115773.0   10000000.0
# ...      ...        ...          ...
# 1058     4.2  1116393.0   50000000.0
# 1059     4.3  4885646.0  100000000.0
# 1060     4.3    10323.0    1000000.0
# 1061     4.1    28301.0    1000000.0
# 1062     4.6   353804.0   10000000.0
#
# [1063 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# One-hot encode the 'Category'
category_encoded = pd.get_dummies(trnc_svd['Category'], prefix='Category')

# Normalize numerical features
scaler = StandardScaler()
numerical_features = scaler.fit_transform(trnc_svd[['Rating', 'Reviews', 'Installs']])

# Combine numerical features with one-hot encoded category
features = pd.concat(
    [pd.DataFrame(numerical_features, columns=['Rating', 'Reviews', 'Installs']), category_encoded],
    axis=1
)

# %%
# Apply SVD
svd = TruncatedSVD(n_components=30, random_state=42)  # Reduce to 50 components
reduced_features = svd.fit_transform(features)

# %%
# Compute cosine similarity
similarity_matrix = cosine_similarity(reduced_features)
similarity_df = pd.DataFrame(similarity_matrix, index=trnc_svd['App'], columns=trnc_svd['App'])

# %%
def recommend_apps(app_name, similarity_df, top_n=10):
    if app_name not in similarity_df.index:
        return "App not found in the dataset."
    
    # Get similarity scores for the app
    similarity_scores = similarity_df.loc[app_name].sort_values(ascending=False)
    
    # Exclude the app itself and return top_n similar apps
    recommendations = similarity_scores.iloc[1:top_n+1].index
    recommendations = trnc_svd[trnc_svd['App'].isin(recommendations)][['App', 'Category', 'Rating']]
    return recommendations

# %%
#with no top rated
recommend_apps('11st', similarity_df, top_n=10)
# Out:
#                                  App  Category  Rating
# 109               Amazon for Tablets  SHOPPING     4.0
# 276                  Boxed Wholesale  SHOPPING     3.8
# 406        CheckPoints 🏆 Rewards App  SHOPPING     4.1
# 408     Checkout 51: Grocery coupons  SHOPPING     4.1
# 419                         Chilindo  SHOPPING     3.8
# 678            Extreme Coupon Finder  SHOPPING     4.1
# 752       Find&Save - Local Shopping  SHOPPING     4.0
# 859                          GS SHOP  SHOPPING     3.8
# 954   Gyft - Mobile Gift Card Wallet  SHOPPING     4.1
# 1001                       HauteLook  SHOPPING     4.1

# %%
def recommend_apps2(app_name, similarity_df, original_df, top_n=10):
    if app_name not in similarity_df.index:
        return "App not found in the dataset."
    
    # Get similarity scores for the app
    similarity_scores = similarity_df.loc[app_name].sort_values(ascending=False)
    
    # Exclude the app itself and get similar apps
    recommended_apps = similarity_scores.iloc[1:].index  # Get all similar apps except the app itself
    
    # Fetch details from the original dataset
    recommendations = original_df[original_df['App'].isin(recommended_apps)][['App', 'Category', 'Rating']]
    
    # Sort recommendations by Rating in descending order and get the top_n
    top_recommendations = recommendations.sort_values(by='Rating', ascending=False).head(top_n)
    
    return top_recommendations

# %%
recommend_apps2('Hotstar', similarity_df, trnc_svd, top_n=10)
# Out:
#                                                    App             Category  \
# 693                                     FREE LIVE TALK               DATING
# 582                      Down Dog: Great Yoga Anywhere   HEALTH_AND_FITNESS
# 524              DMV Permit Practice Test 2018 Edition    AUTO_AND_VEHICLES
# 314                     CDL Practice Test 2018 Edition    AUTO_AND_VEHICLES
# 852                       GPS Speedometer and Odometer  MAPS_AND_NAVIGATION
# 468                              CompTIA Exam Training               FAMILY
# 112                       Amino: Communities and Chats               SOCIAL
# 529  DU Recorder – Screen Recorder, Video Editor, Live        VIDEO_PLAYERS
# 442                           Classical music for baby            PARENTING
# 650                               English Grammar Test            EDUCATION
#
#      Rating
# 693     4.9
# 582     4.9
# 524     4.9
# 314     4.9
# 852     4.8
# 468     4.8
# 112     4.8
# 529     4.8
# 442     4.8
# 650     4.8

# %%
plt.scatter(scaled_ft['Rating'], cat_cluster['Category_Encoded'], 
            c=cat_cluster['Cluster'], cmap='viridis')
plt.xlabel("Category_Encoded")
plt.ylabel("Rating")
plt.title("K-Means Clustering")
plt.colorbar(label='Cluster')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Plotting the data
scatter = ax.scatter(
    cat_cluster['Rating'],
    cat_cluster['Category_Encoded'],
    cat_cluster['Installs'],
    c=cat_cluster['Cluster'],
    cmap='viridis'
)

# Adding labels and title
ax.set_xlabel("Rating")
ax.set_ylabel("Category_Encoded")
ax.set_zlabel("Installs")
ax.set_title("3D K-Means Clustering")

# Adding colorbar for clusters
cb = fig.colorbar(scatter, ax=ax, pad=0.1)
cb.set_label("Cluster")

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Plotting the data
scatter = ax.scatter(
    scaled_ft['Rating'],
    cat_cluster['Category_Encoded'],
    scaled_ft['Reviews'],
    c=cat_cluster['Cluster'],
    cmap='viridis'
)

# Adding labels and title
ax.set_xlabel("Rating")
ax.set_ylabel("Category_Encoded")
ax.set_zlabel("Reviews")
ax.set_title("3D K-Means Clustering")

# Adding colorbar for clusters
cb = fig.colorbar(scatter, ax=ax, pad=0.1)
cb.set_label("Cluster")

plt.show()

# %%
cat_cluster
# Out:
#                                                    App            Category  \
# 0                                10 Best Foods for You  HEALTH_AND_FITNESS
# 1                                                 11st            SHOPPING
# 2                           1800 Contacts - Lens Store             MEDICAL
# 3                      1LINE – One Line with One Touch                GAME
# 4     2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif     PERSONALIZATION
# ...                                                ...                 ...
# 1058    Hotspot Shield Free VPN Proxy & Wi-Fi Security               TOOLS
# 1059                                           Hotstar       ENTERTAINMENT
# 1060                    Hotwire Hotel & Car Rental App    TRAVEL_AND_LOCAL
# 1061                    Housing-Real Estate & Property           LIFESTYLE
# 1062                       Houzz Interior Design Ideas      HOUSE_AND_HOME
#
#       Rating    Reviews     Installs  Cluster  Category_Encoded
# 0        4.0     2490.0     500000.0        0                15
# 1        3.8    48732.0   10000000.0        1                26
# 2        4.7    23160.0    1000000.0        3                20
# 3        4.6   214878.0   10000000.0        0                14
# 4        4.2   115773.0   10000000.0        3                23
# ...      ...        ...          ...      ...               ...
# 1058     4.2  1116393.0   50000000.0        1                29
# 1059     4.3  4885646.0  100000000.0        4                 9
# 1060     4.3    10323.0    1000000.0        1                30
# 1061     4.1    28301.0    1000000.0        3                18
# 1062     4.6   353804.0   10000000.0        0                16
#
# [1063 rows x 7 columns]
